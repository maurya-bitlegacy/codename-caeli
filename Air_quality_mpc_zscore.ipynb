# %%
import numpy as np
import pandas as pd
import csv
import json
import statistics

# %%
with open('neighbors.csv', newline='') as f:
    reader = csv.reader(f)
    neighbor_list = list(reader)
neighbor_list
# Out:
# [['state/ut', 'neighbors'],
#  ['Andhra Pradesh',
#   'Odisha',
#   'Chhattisgarh',
#   'Maharashtra',
#   'Karnataka',
#   'Tamil Nadu'],
#  ['Arunachal Pradesh', 'Assam', 'Nagaland'],
#  ['Assam',
#   'Arunachal Pradesh',
#   'Nagaland',
#   'Manipur',
#   'Mizoram',
#   'Meghalaya',
#   'West Bengal'],
#  ['Bihar', 'Uttar Pradesh', 'Jharkhand', 'West Bengal'],
#  ['Chhattisgarh',
#   'Uttar Pradesh',
#   'Jharkhand',
#   'Odisha',
#   'Madhya Pradesh',
#   'Maharashtra',
#   'Andhra Pradesh'],
#  ['Goa', 'Maharashtra', 'Karnataka'],
#  ['Gujarat',
#   'Rajasthan',
#   'Madhya Pradesh',
#   'Maharashtra',
#   'Dadra & Nagar Haveli',
#   'Daman & Diu'],
#  ['Haryana',
#   'Delhi',
#   'Uttar Pradesh',
#   'Himachal Pradesh',
#   'Punjab',
#   'Rajasthan',
#   'Chandigarh'],
#  ['Himachal Pradesh',
#   'Jammu & Kashmir',
#   'Punjab',
#   'Haryana',
#   'Uttarakhand',
#   'Uttar Pradesh'],
#  ['Jammu & Kashmir', 'Himachal Pradesh', 'Punjab'],
#  ['Jharkhand',
#   'Bihar',
#   'West Bengal',
#   'Odisha',
#   'Chhattisgarh',
#   'Uttar Pradesh'],
#  ['Karnataka', 'Maharashtra', 'Andhra Pradesh', 'Tamil Nadu', 'Kerala', 'Goa'],
#  ['Kerala', 'Karnataka', 'Tamil Nadu'],
#  ['Madhya Pradesh',
#   'Rajasthan',
#   'Uttar Pradesh',
#   'Chhattisgarh',
#   'Maharashtra',
#   'Gujarat'],
#  ['Maharashtra',
#   'Gujarat',
#   'Madhya Pradesh',
#   'Chhattisgarh',
#   'Andhra Pradesh',
#   'Karnataka',
#   'Goa',
#   'Dadra & Nagar Haveli'],
#  ['Manipur', 'Nagaland', 'Mizoram', 'Assam'],
#  ['Meghalaya', 'Assam'],
#  ['Mizoram', 'Manipur', 'Assam'],
#  ['Nagaland', 'Arunachal Pradesh', 'Assam', 'Manipur'],
#  ['Odisha', 'West Bengal', 'Jharkhand', 'Chhattisgarh', 'Andhra Pradesh'],
#  ['Punjab',
#   'Jammu & Kashmir',
#   'Himachal Pradesh',
#   'Haryana',
#   'Rajasthan',
#   'Chandigarh'],
#  ['Rajasthan',
#   'Punjab',
#   'Haryana',
#   'Uttar Pradesh',
#   'Madhya Pradesh',
#   'Gujarat'],
#  ['Sikkim', 'West Bengal'],
#  ['Tamil Nadu', 'Kerala', 'Karnataka', 'Andhra Pradesh', 'Puducherry'],
#  ['Uttarakhand', 'Himachal Pradesh', 'Uttar Pradesh'],
#  ['Uttar Pradesh',
#   'Uttarakhand',
#   'Himachal Pradesh',
#   'Haryana',
#   'Rajasthan',
#   'Madhya Pradesh',
#   'Chhattisgarh',
#   'Jharkhand',
#   'Bihar',
#   'Delhi'],
#  ['West Bengal', 'Sikkim', 'Assam', 'Bihar', 'Jharkhand', 'Odisha'],
#  ['Chandigarh', 'Punjab', 'Haryana'],
#  ['Dadra & Nagar Haveli', 'Gujarat', 'Maharashtra'],
#  ['Daman & Diu', 'Gujarat'],
#  ['Delhi', 'Haryana', 'Uttar Pradesh'],
#  ['Puducherry', 'Tamil Nadu']]

# %%
len(neighbor_list)
# Out:
# 33

# %%
neighbor={}
for i in range(1,33):
    neighbor[neighbor_list[i][0]]=neighbor_list[i][1:]
neighbor
# Out:
# {'Andhra Pradesh': ['Odisha',
#   'Chhattisgarh',
#   'Maharashtra',
#   'Karnataka',
#   'Tamil Nadu'],
#  'Arunachal Pradesh': ['Assam', 'Nagaland'],
#  'Assam': ['Arunachal Pradesh',
#   'Nagaland',
#   'Manipur',
#   'Mizoram',
#   'Meghalaya',
#   'West Bengal'],
#  'Bihar': ['Uttar Pradesh', 'Jharkhand', 'West Bengal'],
#  'Chhattisgarh': ['Uttar Pradesh',
#   'Jharkhand',
#   'Odisha',
#   'Madhya Pradesh',
#   'Maharashtra',
#   'Andhra Pradesh'],
#  'Goa': ['Maharashtra', 'Karnataka'],
#  'Gujarat': ['Rajasthan',
#   'Madhya Pradesh',
#   'Maharashtra',
#   'Dadra & Nagar Haveli',
#   'Daman & Diu'],
#  'Haryana': ['Delhi',
#   'Uttar Pradesh',
#   'Himachal Pradesh',
#   'Punjab',
#   'Rajasthan',
#   'Chandigarh'],
#  'Himachal Pradesh': ['Jammu & Kashmir',
#   'Punjab',
#   'Haryana',
#   'Uttarakhand',
#   'Uttar Pradesh'],
#  'Jammu & Kashmir': ['Himachal Pradesh', 'Punjab'],
#  'Jharkhand': ['Bihar',
#   'West Bengal',
#   'Odisha',
#   'Chhattisgarh',
#   'Uttar Pradesh'],
#  'Karnataka': ['Maharashtra', 'Andhra Pradesh', 'Tamil Nadu', 'Kerala', 'Goa'],
#  'Kerala': ['Karnataka', 'Tamil Nadu'],
#  'Madhya Pradesh': ['Rajasthan',
#   'Uttar Pradesh',
#   'Chhattisgarh',
#   'Maharashtra',
#   'Gujarat'],
#  'Maharashtra': ['Gujarat',
#   'Madhya Pradesh',
#   'Chhattisgarh',
#   'Andhra Pradesh',
#   'Karnataka',
#   'Goa',
#   'Dadra & Nagar Haveli'],
#  'Manipur': ['Nagaland', 'Mizoram', 'Assam'],
#  'Meghalaya': ['Assam'],
#  'Mizoram': ['Manipur', 'Assam'],
#  'Nagaland': ['Arunachal Pradesh', 'Assam', 'Manipur'],
#  'Odisha': ['West Bengal', 'Jharkhand', 'Chhattisgarh', 'Andhra Pradesh'],
#  'Punjab': ['Jammu & Kashmir',
#   'Himachal Pradesh',
#   'Haryana',
#   'Rajasthan',
#   'Chandigarh'],
#  'Rajasthan': ['Punjab',
#   'Haryana',
#   'Uttar Pradesh',
#   'Madhya Pradesh',
#   'Gujarat'],
#  'Sikkim': ['West Bengal'],
#  'Tamil Nadu': ['Kerala', 'Karnataka', 'Andhra Pradesh', 'Puducherry'],
#  'Uttarakhand': ['Himachal Pradesh', 'Uttar Pradesh'],
#  'Uttar Pradesh': ['Uttarakhand',
#   'Himachal Pradesh',
#   'Haryana',
#   'Rajasthan',
#   'Madhya Pradesh',
#   'Chhattisgarh',
#   'Jharkhand',
#   'Bihar',
#   'Delhi'],
#  'West Bengal': ['Sikkim', 'Assam', 'Bihar', 'Jharkhand', 'Odisha'],
#  'Chandigarh': ['Punjab', 'Haryana'],
#  'Dadra & Nagar Haveli': ['Gujarat', 'Maharashtra'],
#  'Daman & Diu': ['Gujarat'],
#  'Delhi': ['Haryana', 'Uttar Pradesh'],
#  'Puducherry': ['Tamil Nadu']}

# %%
with open('Final_Air_Quality_Data.csv', newline='') as f:
    reader = csv.reader(f)
    air_quality_list = list(reader)
air_quality_list
# Out:
# [['State', 'Year', 'so2', 'no2', 'rspm'],
#  ['Andhra Pradesh',
#   '2005',
#   '6.1059125960000005',
#   '30.12773006',
#   '79.36053593'],
#  ['Andhra Pradesh', '2006', '7.933035714', '27.64162103', '85.93876435'],
#  ['Andhra Pradesh', '2007', '6.538941117999999', '27.03730826', '81.51388212'],
#  ['Andhra Pradesh', '2008', '6.935286103999999', '25.31024955', '82.35834813'],
#  ['Andhra Pradesh',
#   '2009',
#   '7.3436222010000005',
#   '22.13510125',
#   '82.74399616'],
#  ['Andhra Pradesh', '2010', '5.365274725', '15.39718805', '69.4872807'],
#  ['Andhra Pradesh', '2011', '4.642877493', '23.96916488', '78.89409673'],
#  ['Andhra Pradesh', '2012', '7.438174274', '15.7628524', '77.66199037'],
#  ['Andhra Pradesh', '2013', '7.379130435', '17.40019861', '76.64749581'],
#  ['Andhra Pradesh', '2014', '8.658371041', '18.58235294', '74.89686291'],
#  ['Arunachal Pradesh',
#   '2005',
#   '1.992983811656848',
#   '10.811324898928977',
#   '76.35110332503852'],
#  ['Arunachal Pradesh',
#   '2006',
#   '2.294911342131937',
#   '10.409247059195213',
#   '66.64280449929419'],
#  ['Arunachal Pradesh',
#   '2007',
#   '2.6417352262395215',
#   '9.885135580695925',
#   '60.34618610772428'],
#  ['Arunachal Pradesh',
#   '2008',
#   '3.586688932335484',
#   '9.710346173484682',
#   '65.21718338402528'],
#  ['Arunachal Pradesh',
#   '2009',
#   '2.8520511333501783',
#   '11.225202357117627',
#   '69.82185408187343'],
#  ['Arunachal Pradesh',
#   '2010',
#   '2.0355464101309835',
#   '6.207139278671154',
#   '60.778610155580246'],
#  ['Arunachal Pradesh',
#   '2011',
#   '1.9645120559797427',
#   '5.809134920382736',
#   '64.35411819436021'],
#  ['Arunachal Pradesh',
#   '2012',
#   '1.8934777018285018',
#   '5.459178164382751',
#   '66.2739657028031'],
#  ['Arunachal Pradesh',
#   '2013',
#   '2.0195004404860395',
#   '5.483520533679032',
#   '86.4334975033006'],
#  ['Arunachal Pradesh', '2014', '2.0', '5.0', '69.4'],
#  ['Assam', '2005', '5.327000000000001', '17.38305085', '111.94845359999998'],
#  ['Assam', '2006', '6.19057117', '16.21029543', '94.94285714'],
#  ['Assam', '2007', '7.359834123', '14.16782811', '84.85821326'],
#  ['Assam', '2008', '6.377758768', '13.45697279', '92.12118644'],
#  ['Assam', '2009', '6.822799097000001', '15.25105105', '96.98274569'],
#  ['Assam', '2010', '7.050862852000001', '15.23251589', '81.74511586'],
#  ['Assam', '2011', '6.567201777999999', '14.59931874', '81.90988463'],
#  ['Assam', '2012', '6.083540704', '13.96612158', '82.07465339'],
#  ['Assam', '2013', '6.94160852', '15.43692618', '124.6814176'],
#  ['Assam', '2014', '6.808833272', '14.05294334', '80.74357090000001'],
#  ['Bihar', '2005', '12.27910448', '34.07017544', '103.38805970000001'],
#  ['Bihar', '2006', '9.98452381', '39.44378698', '111.0828402'],
#  ['Bihar', '2007', '9.74519774', '41.575', '116.3621622'],
#  ['Bihar', '2008', '6.8644859810000005', '38.31181818', '118.6544118'],
#  ['Bihar', '2009', '4.708695652', '32.61746032', '98.47761194'],
#  ['Bihar', '2010', '6.4879999999999995', '36.11678832', '165.2805755'],
#  ['Bihar', '2011', '4.25', '35.734375', '158.030303'],
#  ['Bihar', '2012', '6.073298428999999', '34.15584416', '161.6639004'],
#  ['Bihar', '2013', '7.896596859', '32.57731331', '165.2974978'],
#  ['Bihar', '2014', '9.719895288', '30.99878247', '168.9310952'],
#  ['Chandigarh', '2005', '5.194155844', '15.70486726', '94.54714286'],
#  ['Chandigarh', '2006', '3.9375', '14.72707965', '105.10028249999999'],
#  ['Chandigarh', '2007', '5.3', '15.55918654', '102.21600000000001'],
#  ['Chandigarh', '2008', '5.3', '15.89756447', '95.54188482'],
#  ['Chandigarh', '2009', '5.8', '15.47037037', '80.83794466'],
#  ['Chandigarh', '2010', '2.0053691280000003', '15.69571046', '91.9704698'],
#  ['Chandigarh', '2011', '2.013636364', '15.81304965', '101.6570188'],
#  ['Chandigarh', '2012', '2.0', '19.62668329', '111.14897579999999'],
#  ['Chandigarh', '2013', '2.007058824', '28.30823529', '101.4462585'],
#  ['Chandigarh', '2014', '2.0', '21.31643836', '91.10641201'],
#  ['Chhattisgarh', '2005', '14.65796388', '26.86367647', '132.65294120000001'],
#  ['Chhattisgarh', '2006', '15.30338733', '26.07316754', '131.2644068'],
#  ['Chhattisgarh', '2007', '14.87588832', '26.07101631', '118.3551637'],
#  ['Chhattisgarh', '2008', '15.90311615', '27.42804533', '127.5099715'],
#  ['Chhattisgarh', '2009', '14.80697674', '26.37445573', '131.3483483'],
#  ['Chhattisgarh', '2010', '11.72620791', '25.56744868', '148.58587480000003'],
#  ['Chhattisgarh', '2011', '11.28235294', '24.57229261', '137.8956469'],
#  ['Chhattisgarh', '2012', '10.31768953', '21.67454545', '98.16985138'],
#  ['Chhattisgarh', '2013', '10.2926045', '22.62439807', '118.06851850000001'],
#  ['Chhattisgarh', '2014', '10.162790699999999', '22.60854093', '116.1321138'],
#  ['Dadra & Nagar Haveli', '2005', '12.21776018', '22.01566742', '80.67024887'],
#  ['Dadra & Nagar Haveli', '2006', '11.42946833', '20.45195136', '84.89394796'],
#  ['Dadra & Nagar Haveli', '2007', '10.64117647', '18.88823529', '89.11764706'],
#  ['Dadra & Nagar Haveli', '2008', '9.852884615', '17.32451923', '93.34134615'],
#  ['Dadra & Nagar Haveli', '2009', '8.589855072', '17.31884058', '71.23188406'],
#  ['Dadra & Nagar Haveli',
#   '2010',
#   '7.138297872000001',
#   '17.61702128',
#   '39.34042553'],
#  ['Dadra & Nagar Haveli', '2011', '7.592783505', '19.35463918', '23.85714286'],
#  ['Dadra & Nagar Haveli', '2012', '7.618666667', '20.18133333', '8.373860182'],
#  ['Dadra & Nagar Haveli',
#   '2013',
#   '7.644549828',
#   '21.00802749',
#   '-7.109422492'],
#  ['Dadra & Nagar Haveli', '2014', '7.67043299', '21.83472165', '-22.59270517'],
#  ['Daman & Diu', '2005', '17.34174757', '21.15006068', '85.62924757'],
#  ['Daman & Diu', '2006', '14.82087379', '19.79065534', '89.09587379'],
#  ['Daman & Diu', '2007', '12.3', '18.43125', '92.5625'],
#  ['Daman & Diu', '2008', '9.779126214', '17.07184466', '96.02912621'],
#  ['Daman & Diu', '2009', '7.273134327999999', '18.83731343', '57.11940299'],
#  ['Daman & Diu', '2010', '7.177083333', '17.65625', '35.32291667'],
#  ['Daman & Diu', '2011', '7.490990991', '19.61171171', '24.0'],
#  ['Daman & Diu', '2012', '7.6289473679999995', '20.14736842', '12.67708333'],
#  ['Daman & Diu',
#   '2013',
#   '7.7669037460000006',
#   '20.68302513',
#   '1.3541666669999999'],
#  ['Daman & Diu', '2014', '7.904860123', '21.21868184', '-9.96875'],
#  ['Delhi', '2005', '9.254005935', '49.02800546', '139.0984081'],
#  ['Delhi', '2006', '9.548440367000001', '46.4290146', '163.2691552'],
#  ['Delhi', '2007', '6.324870466', '48.81644295', '175.8226415'],
#  ['Delhi', '2008', '7.091782946', '58.36153846', '218.01754390000002'],
#  ['Delhi', '2009', '6.48685446', '50.07406877', '251.41358939999998'],
#  ['Delhi', '2010', '5.905995536', '54.28293602', '236.80955330000003'],
#  ['Delhi', '2011', '5.325136612', '58.49180328', '222.20551719999997'],
#  ['Delhi', '2012', '7.444444444', '81.68402778', '236.79861110000002'],
#  ['Delhi', '2013', '4.487084871', '89.73431734', '228.2103321'],
#  ['Delhi', '2014', '5.1371742110000005', '63.49245542', '217.11312850000002'],
#  ['Goa', '2005', '11.59047619', '15.20263158', '52.3'],
#  ['Goa', '2006', '10.32222222', '11.34975124', '49.83386581'],
#  ['Goa', '2007', '4.411363636', '13.72449799', '50.45245902'],
#  ['Goa', '2008', '4.366666667', '15.45', '94.0'],
#  ['Goa', '2009', '5.465079365', '14.19579832', '71.23134328'],
#  ['Goa', '2010', '12.3373494', '21.53719008', '68.00655738'],
#  ['Goa', '2011', '8.651013874', '16.52991453', '94.4493063'],
#  ['Goa', '2012', '6.2318840579999994', '17.44927536', '81.36764706'],
#  ['Goa', '2013', '7.047949527', '11.904040400000001', '53.37660747'],
#  ['Goa', '2014', '3.259259259', '7.527777778', '55.59259259'],
#  ['Gujarat', '2005', '17.21020283', '27.72972973', '126.27429270000002'],
#  ['Gujarat', '2006', '16.40711538', '25.74955128', '114.6014121'],
#  ['Gujarat', '2007', '16.4303283', '25.436875', '95.7867151'],
#  ['Gujarat', '2008', '14.22519045', '22.66922296', '87.79776989'],
#  ['Gujarat', '2009', '16.12158155', '23.94510989', '91.96547945'],
#  ['Gujarat', '2010', '15.47908163', '23.01632653', '88.46173469'],
#  ['Gujarat', '2011', '14.94366925', '25.14470284', '88.33693972'],
#  ['Gujarat', '2012', '15.25853018', '26.37270341', '94.93350394'],
#  ['Gujarat', '2013', '12.74455446', '18.74083113', '85.95981555'],
#  ['Gujarat', '2014', '14.25557028', '20.13089705', '87.00719152'],
#  ['Haryana', '2005', '10.57364341', '22.7788', '127.0760095'],
#  ['Haryana', '2006', '10.15978836', '19.49045936', '146.50379750000002'],
#  ['Haryana', '2007', '8.061581921', '12.17770701', '110.4692737'],
#  ['Haryana', '2008', '9.668032787000001', '14.19416667', '166.04918030000002'],
#  ['Haryana', '2009', '12.69411765', '27.29117647', '274.94117650000004'],
#  ['Haryana', '2010', '14.6344086', '23.67204301', '161.577957'],
#  ['Haryana', '2011', '13.70227273', '27.79545455', '143.929385'],
#  ['Haryana', '2012', '9.711340206000001', '27.85910653', '159.664433'],
#  ['Haryana', '2013', '12.16814159', '25.92035398', '190.6283186'],
#  ['Haryana', '2014', '13.11061947', '24.34955752', '178.38495580000003'],
#  ['Himachal Pradesh', '2005', '5.277456647', '16.7752', '39.34615385'],
#  ['Himachal Pradesh', '2006', '4.889176829', '15.58455657', '91.27146172'],
#  ['Himachal Pradesh', '2007', '3.601996008', '13.21361186', '87.34767025'],
#  ['Himachal Pradesh', '2008', '3.247016706', '12.43525881', '107.465847'],
#  ['Himachal Pradesh', '2009', '3.536916549', '14.28350669', '96.43218552'],
#  ['Himachal Pradesh', '2010', '2.756587202', '14.69806613', '102.706422'],
#  ['Himachal Pradesh', '2011', '2.558982684', '12.41556064', '92.99582289'],
#  ['Himachal Pradesh', '2012', '2.054054054', '14.09573811', '92.93574828'],
#  ['Himachal Pradesh', '2013', '2.159065804', '14.25257344', '91.19899147'],
#  ['Himachal Pradesh',
#   '2014',
#   '2.1472187369999998',
#   '14.10376569',
#   '89.68555108'],
#  ['Jammu & Kashmir', '2005', '16.3748538', '2.725964912', '50.73187638'],
#  ['Jammu & Kashmir', '2006', '14.38877193', '5.042105263', '62.92124771'],
#  ['Jammu & Kashmir',
#   '2007',
#   '12.40269006',
#   '7.358245613999999',
#   '75.11061904'],
#  ['Jammu & Kashmir', '2008', '10.41660819', '9.674385965', '87.29999037'],
#  ['Jammu & Kashmir', '2009', '8.430526316', '11.99052632', '99.4893617'],
#  ['Jammu & Kashmir',
#   '2010',
#   '6.444444444',
#   '14.30666667',
#   '111.67873300000001'],
#  ['Jammu & Kashmir',
#   '2011',
#   '5.301587302',
#   '11.85483871',
#   '105.93548390000001'],
#  ['Jammu & Kashmir',
#   '2012',
#   '5.811881187999999',
#   '12.3019802',
#   '119.46078429999999'],
#  ['Jammu & Kashmir',
#   '2013',
#   '14.74137931',
#   '4.771551724',
#   '118.09333329999998'],
#  ['Jammu & Kashmir', '2014', '5.38121547', '12.64088398', '122.9888268'],
#  ['Jharkhand', '2005', '26.23721461', '49.41369863', '141.5272727'],
#  ['Jharkhand', '2006', '32.2221374', '52.89847328', '150.70229009999997'],
#  ['Jharkhand', '2007', '26.06073298', '49.71239092', '147.86585369999997'],
#  ['Jharkhand',
#   '2008',
#   '25.671150100000002',
#   '44.04035088',
#   '161.55086369999998'],
#  ['Jharkhand', '2009', '25.65011038', '42.80265487', '186.91452990000002'],
#  ['Jharkhand', '2010', '23.51409922', '39.51568093', '190.1105337'],
#  ['Jharkhand', '2011', '21.25710419', '38.37618403', '189.69647700000002'],
#  ['Jharkhand', '2012', '22.75766871', '41.5', '174.19969740000002'],
#  ['Jharkhand', '2013', '22.32160994', '40.95242636', '151.1040022'],
#  ['Jharkhand', '2014', '13.86333333', '36.15946844', '162.92739269999998'],
#  ['Karnataka',
#   '2005',
#   '10.36987952',
#   '35.136027399999996',
#   '60.72976189999999'],
#  ['Karnataka', '2006', '12.82259714', '26.53690037', '62.17183771'],
#  ['Karnataka', '2007', '12.4324941', '25.47341326', '74.64857342'],
#  ['Karnataka', '2008', '11.86115917', '26.16227371', '77.71026012'],
#  ['Karnataka', '2009', '10.84955117', '26.63793103', '81.78676471'],
#  ['Karnataka', '2010', '10.59082597', '23.8149821', '76.13743426'],
#  ['Karnataka', '2011', '10.33210077', '20.99203317', '70.48810382'],
#  ['Karnataka', '2012', '11.25337423', '23.38499562', '87.8461525'],
#  ['Karnataka', '2013', '8.545924968', '18.00948685', '82.10349288'],
#  ['Karnataka', '2014', '8.320222317', '18.55964087', '88.74902131'],
#  ['Kerala', '2005', '9.935363458', '19.35619048', '69.42302879'],
#  ['Kerala', '2006', '9.6569161', '17.91897321', '67.73349244'],
#  ['Kerala', '2007', '8.001632653', '17.14801619', '51.50632111'],
#  ['Kerala', '2008', '6.945961003', '17.65121212', '47.52313625'],
#  ['Kerala', '2009', '6.62', '16.51970569', '46.56495468'],
#  ['Kerala', '2010', '4.336634892', '13.54105481', '42.88237061'],
#  ['Kerala', '2011', '4.227283558', '14.04636472', '42.54845115'],
#  ['Kerala', '2012', '3.9516660939999997', '12.104191', '54.38852628'],
#  ['Kerala', '2013', '3.858992537', '11.36108209', '55.17313433'],
#  ['Kerala', '2014', '4.168224298999999', '12.57568296', '50.96345555'],
#  ['Madhya Pradesh', '2005', '12.52272727', '18.70327613', '96.03003003'],
#  ['Madhya Pradesh', '2006', '11.26710744', '16.54239631', '100.9471429'],
#  ['Madhya Pradesh',
#   '2007',
#   '10.90345763',
#   '17.34478417',
#   '107.18421049999999'],
#  ['Madhya Pradesh',
#   '2008',
#   '11.85228712',
#   '18.74419643',
#   '127.13072690000001'],
#  ['Madhya Pradesh',
#   '2009',
#   '11.50992301',
#   '17.90126283',
#   '121.87161640000001'],
#  ['Madhya Pradesh', '2010', '11.29500209', '17.18102838', '133.9099583'],
#  ['Madhya Pradesh', '2011', '12.10693312', '19.46205502', '136.3392467'],
#  ['Madhya Pradesh', '2012', '12.5041828', '21.04043377', '124.31010719999999'],
#  ['Madhya Pradesh',
#   '2013',
#   '12.21067024',
#   '22.15042934',
#   '145.06154890000002'],
#  ['Madhya Pradesh',
#   '2014',
#   '10.61300505',
#   '18.66023647',
#   '121.44910870000001'],
#  ['Maharashtra', '2005', '20.35380522', '29.42313764', '94.38078902'],
#  ['Maharashtra', '2006', '18.29846626', '28.80648211', '83.58702659'],
#  ['Maharashtra', '2007', '18.45968639', '29.62043119', '90.99851190000001'],
#  ['Maharashtra', '2008', '17.86620097', '32.13819622', '101.1085252'],
#  ['Maharashtra', '2009', '15.45322444', '30.68197505', '97.06031077'],
#  ['Maharashtra', '2010', '17.09538421', '30.53904543', '99.75789387'],
#  ['Maharashtra', '2011', '17.42454473', '33.63604743', '111.09370559999999'],
#  ['Maharashtra', '2012', '16.80245855', '33.09319611', '103.64783390000001'],
#  ['Maharashtra', '2013', '16.61453943', '31.83747178', '100.0633775'],
#  ['Maharashtra', '2014', '18.14534974', '35.74793582', '105.91169599999999'],
#  ['Manipur',
#   '2005',
#   '2.492361015525382',
#   '26.833017697134323',
#   '77.53337645124309'],
#  ['Manipur',
#   '2006',
#   '3.3192239900960985',
#   '23.806394879145387',
#   '77.51137276373667'],
#  ['Manipur', '2007', '3.5111111110000004', '20.5375', '64.67857143'],
#  ['Manipur', '2008', '4.9', '19.155', '84.2'],
#  ['Manipur',
#   '2009',
#   '3.6249296877658366',
#   '20.494279054019717',
#   '80.76527385444973'],
#  ['Manipur',
#   '2010',
#   '2.756289188884278',
#   '15.216269336872083',
#   '75.40610931281604'],
#  ['Manipur',
#   '2011',
#   '2.65590058786533',
#   '14.677549807645109',
#   '77.60972269275611'],
#  ['Manipur',
#   '2012',
#   '2.555511986846383',
#   '15.50901547162806',
#   '89.09318361583519'],
#  ['Manipur',
#   '2013',
#   '2.7758534344385843',
#   '15.657954350678523',
#   '99.20927703937066'],
#  ['Manipur',
#   '2014',
#   '2.718711369711805',
#   '14.338558708266069',
#   '85.1240999359407'],
#  ['Meghalaya', '2005', '6.081904762000001', '12.41409797', '56.41176471'],
#  ['Meghalaya', '2006', '5.347619048', '13.07962963', '60.875'],
#  ['Meghalaya', '2007', '4.613333333', '13.74516129', '65.33823529'],
#  ['Meghalaya', '2008', '22.0', '18.0258427', '71.53846154'],
#  ['Meghalaya', '2009', '6.0', '12.06760563', '77.86046512'],
#  ['Meghalaya', '2010', '24.18878505', '10.88961578', '103.4953271'],
#  ['Meghalaya', '2011', '17.43881857', '10.31223629', '90.00632911'],
#  ['Meghalaya', '2012', '8.595294118', '10.96331765', '72.57908235'],
#  ['Meghalaya', '2013', '5.369734789', '9.752336449', '58.67550702'],
#  ['Meghalaya', '2014', '4.875205255', '10.26108374', '56.85690789'],
#  ['Mizoram',
#   '2005',
#   '1.8359999999999999',
#   '13.349889800000001',
#   '27.85628743'],
#  ['Mizoram', '2006', '3.568', '10.70301508', '38.85765125'],
#  ['Mizoram', '2007', '5.3', '8.056140351', '39.689419799999996'],
#  ['Mizoram', '2008', '4.2', '7.246285714', '37.30420712'],
#  ['Mizoram', '2009', '3.1', '6.379446276', '39.45018048'],
#  ['Mizoram', '2010', '2.0', '5.512606838', '41.59615385'],
#  ['Mizoram', '2011', '2.0', '5.537590164', '39.52178649'],
#  ['Mizoram', '2012', '2.0', '7.095744681', '54.32624113'],
#  ['Mizoram', '2013', '2.13856034', '6.701168717000001', '48.71616872'],
#  ['Mizoram', '2014', '2.0415204680000003', '6.189473684', '43.06988304'],
#  ['Nagaland', '2005', '2.421235521', '14.76', '79.76470588'],
#  ['Nagaland', '2006', '2.7714285710000004', '14.39009434', '72.98584906'],
#  ['Nagaland', '2007', '3.1216216219999997', '14.08269231', '67.44230769'],
#  ['Nagaland', '2008', '5.3', '13.99027778', '72.38425926'],
#  ['Nagaland', '2009', '3.7', '16.27666667', '79.48888889'],
#  ['Nagaland', '2010', '2.0', '6.68748801', '72.44244604'],
#  ['Nagaland', '2011', '2.0', '6.141826922999999', '82.34134615'],
#  ['Nagaland', '2012', '2.0', '5.688041925', '87.56388916'],
#  ['Nagaland', '2013', '2.0', '5.234256927', '92.78643216'],
#  ['Nagaland', '2014', '2.0', '4.780471929', '98.00897516'],
#  ['Odisha', '2005', '5.254074074', '15.03807391', '76.6987315'],
#  ['Odisha', '2006', '5.206242906', '16.0534712', '77.80100937'],
#  ['Odisha', '2007', '5.591397849', '15.76695122', '76.35870889'],
#  ['Odisha', '2008', '6.479314158999999', '17.299751399999998', '83.73523928'],
#  ['Odisha', '2009', '6.544191617', '17.85108055', '84.86378520000001'],
#  ['Odisha', '2010', '4.268662919', '17.69545271', '84.80456349'],
#  ['Odisha', '2011', '2.1527377519999997', '18.5949422', '92.93467819'],
#  ['Odisha', '2012', '4.113880814', '16.88819041', '84.72318314'],
#  ['Odisha', '2013', '4.08667288', '17.02096925', '85.95324635'],
#  ['Odisha', '2014', '5.016246259', '18.07182557', '89.83283454'],
#  ['Puducherry', '2005', '15.67619048', '14.58832117', '50.78571429'],
#  ['Puducherry', '2006', '9.648905109', '11.03424125', '58.64035088'],
#  ['Puducherry', '2007', '4.523580786', '8.118932039', '49.82909091'],
#  ['Puducherry', '2008', '4.67029703', '11.06509434', '48.38'],
#  ['Puducherry', '2009', '2.972972973', '7.714285714', '40.37209302'],
#  ['Puducherry', '2010', '5.829039216', '13.09608497', '37.67464052'],
#  ['Puducherry', '2011', '7.233789954', '15.58928571', '41.87012987'],
#  ['Puducherry', '2012', '7.506666667', '13.75555556', '40.117391299999994'],
#  ['Puducherry', '2013', '6.196850394', '13.743082999999999', '42.88235294'],
#  ['Puducherry', '2014', '9.01511335', '12.34508816', '39.97506234'],
#  ['Punjab', '2005', '15.67136061', '32.53339676', '219.50344040000002'],
#  ['Punjab', '2006', '12.25263944', '31.42722748', '215.58547009999998'],
#  ['Punjab', '2007', '11.15485481', '32.21637188', '200.5820992'],
#  ['Punjab', '2008', '10.13460965', '30.59220844', '218.2324094'],
#  ['Punjab', '2009', '9.423045977000001', '29.12132184', '203.8932677'],
#  ['Punjab', '2010', '10.45248869', '27.254399199999998', '193.60300669999998'],
#  ['Punjab', '2011', '10.16016446', '26.05633288', '164.5903064'],
#  ['Punjab', '2012', '9.644793926', '27.04747188', '161.57325480000003'],
#  ['Punjab', '2013', '9.639264264', '25.06722222', '156.301107'],
#  ['Punjab', '2014', '9.002353864', '23.93652561', '131.9506627'],
#  ['Rajasthan', '2005', '7.539305402', '24.79356322', '105.063571'],
#  ['Rajasthan', '2006', '6.834328358', '25.84310602', '122.65815819999999'],
#  ['Rajasthan',
#   '2007',
#   '6.924216112000001',
#   '24.87784749',
#   '115.46976969999999'],
#  ['Rajasthan', '2008', '6.859831461000001', '28.88460459', '129.3512761'],
#  ['Rajasthan', '2009', '6.284865135', '27.88832918', '130.1223691'],
#  ['Rajasthan', '2010', '6.730209664', '29.90296501', '164.4673546'],
#  ['Rajasthan', '2011', '6.890348661', '29.62455786', '162.93995959999998'],
#  ['Rajasthan', '2012', '8.445841121', '37.45882432', '166.5382302'],
#  ['Rajasthan', '2013', '6.993220339', '30.23291138', '172.7112721'],
#  ['Rajasthan', '2014', '7.420108409', '34.51190234', '161.61029409999998'],
#  ['Sikkim',
#   '2005',
#   '25.954615802945753',
#   '23.87186760644132',
#   '38.02279874360152'],
#  ['Sikkim',
#   '2006',
#   '19.224957057022458',
#   '25.796375699223105',
#   '35.5737707095953'],
#  ['Sikkim', '2007', '19.8', '26.8', '32.0'],
#  ['Sikkim',
#   '2008',
#   '23.067420890010432',
#   '30.42004771548279',
#   '33.624071112867284'],
#  ['Sikkim',
#   '2009',
#   '32.65874091896912',
#   '29.40333615740963',
#   '47.92002248525954'],
#  ['Sikkim',
#   '2010',
#   '25.26187210771064',
#   '29.20088488494366',
#   '34.34208627665281'],
#  ['Sikkim',
#   '2011',
#   '44.663148215797534',
#   '25.736703094162127',
#   '36.99700705366201'],
#  ['Sikkim',
#   '2012',
#   '107.94808643695626',
#   '24.716763750624633',
#   '33.50149366027268'],
#  ['Sikkim',
#   '2013',
#   '27.249208067790182',
#   '28.84754786186659',
#   '49.70684053569369'],
#  ['Sikkim',
#   '2014',
#   '21.05195432570956',
#   '26.0468639054235',
#   '36.395599595346525'],
#  ['Tamil Nadu', '2005', '11.88474576', '25.56024279', '54.92496392'],
#  ['Tamil Nadu', '2006', '12.5658749', '25.96273734', '58.30634072'],
#  ['Tamil Nadu', '2007', '13.55475483', '21.83539955', '64.96441809'],
#  ['Tamil Nadu', '2008', '13.36700361', '21.85787572', '68.82201714'],
#  ['Tamil Nadu', '2009', '11.17064579', '20.98751229', '71.94785847'],
#  ['Tamil Nadu', '2010', '9.04994234', '19.51682933', '69.929766'],
#  ['Tamil Nadu', '2011', '10.28891736', '22.24311339', '78.18577835'],
#  ['Tamil Nadu', '2012', '10.43301998', '20.65865023', '72.46574579'],
#  ['Tamil Nadu', '2013', '11.81006768', '21.69519393', '71.60225376'],
#  ['Tamil Nadu', '2014', '11.50313808', '22.13677599', '62.49426087'],
#  ['Uttar Pradesh', '2005', '13.55471175', '24.82154846', '173.43361240000002'],
#  ['Uttar Pradesh', '2006', '12.19401709', '25.49464761', '177.0767235'],
#  ['Uttar Pradesh', '2007', '13.55151125', '27.59964953', '169.8552788'],
#  ['Uttar Pradesh', '2008', '12.18621968', '29.14155556', '181.7239875'],
#  ['Uttar Pradesh', '2009', '11.25663647', '28.13715302', '178.1990206'],
#  ['Uttar Pradesh', '2010', '12.7402324', '30.65908603', '183.30806030000002'],
#  ['Uttar Pradesh', '2011', '11.04288079', '29.35063649', '161.1969408'],
#  ['Uttar Pradesh', '2012', '13.0896107', '29.98856761', '190.1923362'],
#  ['Uttar Pradesh', '2013', '10.6071076', '26.90496071', '184.7217899'],
#  ['Uttar Pradesh', '2014', '10.42651007', '26.92901206', '179.32303180000002'],
#  ['Uttarakhand', '2005', '21.5877551', '25.83265306', '152.862069'],
#  ['Uttarakhand', '2006', '25.29518072', '27.95180723', '120.37931029999999'],
#  ['Uttarakhand', '2007', '25.41728395', '27.6345679', '100.2738095'],
#  ['Uttarakhand', '2008', '25.55384615', '26.42307692', '124.6388889'],
#  ['Uttarakhand', '2009', '26.92117308', '28.28538846', '138.0262882'],
#  ['Uttarakhand', '2010', '28.2885', '30.1477', '151.4136875'],
#  ['Uttarakhand', '2011', '22.4905641', '24.2680812', '159.7810293'],
#  ['Uttarakhand', '2012', '26.54666667', '29.17333333', '180.4158553'],
#  ['Uttarakhand', '2013', '23.45502646', '25.78571429', '141.8446154'],
#  ['Uttarakhand', '2014', '20.36338624', '22.39809524', '103.2733755'],
#  ['West Bengal', '2005', '9.957436399', '52.80493023', '120.4730483'],
#  ['West Bengal', '2006', '7.375616292', '57.06197108', '112.713444'],
#  ['West Bengal', '2007', '7.596230366', '59.28200313', '101.3901573'],
#  ['West Bengal', '2008', '8.84976985', '67.28960313', '106.5359331'],
#  ['West Bengal', '2009', '12.52946058', '65.04062187', '151.83183180000003'],
#  ['West Bengal', '2010', '9.691666667', '64.59279661', '108.81092279999999'],
#  ['West Bengal', '2011', '17.13492741', '56.92997438', '117.22288640000001'],
#  ['West Bengal', '2012', '41.41406728', '54.67385321', '106.14755349999999'],
#  ['West Bengal', '2013', '10.45410413', '63.8112098', '157.4932619'],
#  ['West Bengal', '2014', '8.076540137', '57.61605476', '115.3173615']]

# %%
air_quality_list=air_quality_list[1:]

# %%
air_quality_mpc={}
i=1
for ele in air_quality_list:
    air_quality_mpc[ele[0]]=air_quality_mpc.get(ele[0],{})
    l=[float(i) for i in ele[2:]]
    air_quality_mpc[ele[0]][ele[1]]= mean(l)
air_quality_mpc
# Out:
# {'Andhra Pradesh': {'2005': 38.531392862,
#   '2006': 40.504473698,
#   '2007': 38.363377166,
#   '2008': 38.20129459466666,
#   '2009': 37.407573203666665,
#   '2010': 30.083247825,
#   '2011': 35.835379701,
#   '2012': 33.62100568133333,
#   '2013': 33.808941618333336,
#   '2014': 34.045862297},
#  'Arunachal Pradesh': {'2005': 29.71847067854145,
#   '2006': 26.448987633540444,
#   '2007': 24.291018971553243,
#   '2008': 26.171406163281816,
#   '2009': 27.966369190780412,
#   '2010': 23.007098614794128,
#   '2011': 24.042588390240898,
#   '2012': 24.54220718967145,
#   '2013': 31.31217282582189,
#   '2014': 25.46666666666667},
#  'Assam': {'2005': 44.886168149999996,
#   '2006': 39.11457458,
#   '2007': 35.461958497666664,
#   '2008': 37.31863933266667,
#   '2009': 39.68553194566667,
#   '2010': 34.676164867333334,
#   '2011': 34.358801715999995,
#   '2012': 34.041438557999996,
#   '2013': 49.0199841,
#   '2014': 33.86844917066667},
#  'Bihar': {'2005': 49.912446540000005,
#   '2006': 53.50371699666667,
#   '2007': 55.89411998,
#   '2008': 54.61023865366667,
#   '2009': 45.267922637333335,
#   '2010': 69.29512127333334,
#   '2011': 66.00489266666666,
#   '2012': 67.29768099633333,
#   '2013': 68.59046932300001,
#   '2014': 69.88325765266666},
#  'Chandigarh': {'2005': 38.482055321333334,
#   '2006': 41.254954049999995,
#   '2007': 41.025062180000006,
#   '2008': 38.91314976333334,
#   '2009': 34.03610501,
#   '2010': 36.55718312933333,
#   '2011': 39.827901604666664,
#   '2012': 44.258553029999995,
#   '2013': 43.920517538,
#   '2014': 38.14095012333333},
#  'Chhattisgarh': {'2005': 58.05819385000001,
#   '2006': 57.54698722333333,
#   '2007': 53.10068944333334,
#   '2008': 56.94704432666667,
#   '2009': 57.50992692333333,
#   '2010': 61.959843796666675,
#   '2011': 57.91676415,
#   '2012': 43.38736212,
#   '2013': 50.32850702333334,
#   '2014': 49.63448181},
#  'Dadra & Nagar Haveli': {'2005': 38.30122549,
#   '2006': 38.925122550000005,
#   '2007': 39.54901960666667,
#   '2008': 40.172916665,
#   '2009': 32.38019323733333,
#   '2010': 21.365248227333332,
#   '2011': 16.934855181666666,
#   '2012': 12.057953393,
#   '2013': 7.1810516086666665,
#   '2014': 2.3041498233333333},
#  'Daman & Diu': {'2005': 41.37368527333334,
#   '2006': 41.23580097333333,
#   '2007': 41.09791666666666,
#   '2008': 40.96003236133333,
#   '2009': 27.743283582666663,
#   '2010': 20.052083334333332,
#   '2011': 17.034234233666666,
#   '2012': 13.484466372666667,
#   '2013': 9.934698514333334,
#   '2014': 6.384930654333333},
#  'Delhi': {'2005': 65.793473165,
#   '2006': 73.082203389,
#   '2007': 76.987984972,
#   '2008': 94.49028843533334,
#   '2009': 102.65817087666666,
#   '2010': 98.999494952,
#   '2011': 95.34081903066665,
#   '2012': 108.642361108,
#   '2013': 107.47724477033333,
#   '2014': 95.24758604366667},
#  'Goa': {'2005': 26.364369256666667,
#   '2006': 23.835279756666665,
#   '2007': 22.862773548666667,
#   '2008': 37.938888889,
#   '2009': 30.297406988333336,
#   '2010': 33.960365620000005,
#   '2011': 39.87674490133333,
#   '2012': 35.016268826,
#   '2013': 24.109532465666668,
#   '2014': 22.126543209},
#  'Gujarat': {'2005': 57.071408420000004,
#   '2006': 52.25269292,
#   '2007': 45.88463946666666,
#   '2008': 41.564061099999996,
#   '2009': 44.01072363,
#   '2010': 42.319047616666666,
#   '2011': 42.80843727,
#   '2012': 45.52157917666666,
#   '2013': 39.14840038,
#   '2014': 40.464552950000005},
#  'Haryana': {'2005': 53.47615097,
#   '2006': 58.71801507333334,
#   '2007': 43.569520877,
#   '2008': 63.30379325233334,
#   '2009': 104.97549020666668,
#   '2010': 66.62813620333333,
#   '2011': 61.80903742666666,
#   '2012': 65.744959912,
#   '2013': 76.23893805666667,
#   '2014': 71.94837759666667},
#  'Himachal Pradesh': {'2005': 20.466270165666668,
#   '2006': 37.248398373,
#   '2007': 34.721092706,
#   '2008': 41.049374172,
#   '2009': 38.084202919666666,
#   '2010': 40.053691777333334,
#   '2011': 35.99012207133333,
#   '2012': 36.36184681466666,
#   '2013': 35.870210238,
#   '2014': 35.31217850233333},
#  'Jammu & Kashmir': {'2005': 23.27756503066667,
#   '2006': 27.450708301000002,
#   '2007': 31.623851571333333,
#   '2008': 35.79699484166667,
#   '2009': 39.970138112,
#   '2010': 44.14328137133334,
#   '2011': 41.03063663733334,
#   '2012': 45.858215229333325,
#   '2013': 45.868754777999996,
#   '2014': 47.00364208333333},
#  'Jharkhand': {'2005': 72.39272864666667,
#   '2006': 78.60763359333332,
#   '2007': 74.54632586666666,
#   '2008': 77.08745489333333,
#   '2009': 85.12243171666667,
#   '2010': 84.38010461666667,
#   '2011': 83.10992174,
#   '2012': 79.48578870333334,
#   '2013': 71.45934616666666,
#   '2014': 70.98339815666667},
#  'Karnataka': {'2005': 35.41188960666666,
#   '2006': 33.843778406666665,
#   '2007': 37.51816026,
#   '2008': 38.577897666666665,
#   '2009': 39.75808230333333,
#   '2010': 36.84774744333333,
#   '2011': 33.93741258666667,
#   '2012': 40.828174116666666,
#   '2013': 36.219634899333336,
#   '2014': 38.542961499},
#  'Kerala': {'2005': 32.90486090933334,
#   '2006': 31.769793916666668,
#   '2007': 25.551989984333332,
#   '2008': 24.040103124333335,
#   '2009': 23.23488679,
#   '2010': 20.253353437333335,
#   '2011': 20.274033142666667,
#   '2012': 23.481461124666666,
#   '2013': 23.464402985666666,
#   '2014': 22.569120936333334},
#  'Madhya Pradesh': {'2005': 42.418677810000005,
#   '2006': 42.91888221666667,
#   '2007': 45.14415076666666,
#   '2008': 52.57573681666667,
#   '2009': 50.42760074666667,
#   '2010': 54.12866292333334,
#   '2011': 55.96941161333333,
#   '2012': 52.618241256666664,
#   '2013': 59.80754949333334,
#   '2014': 50.24078340666667},
#  'Maharashtra': {'2005': 48.05257729333333,
#   '2006': 43.56399165333333,
#   '2007': 46.35954316,
#   '2008': 50.37097413,
#   '2009': 47.73183675333333,
#   '2010': 49.130774503333335,
#   '2011': 54.051432586666664,
#   '2012': 51.18116285333333,
#   '2013': 49.50512957,
#   '2014': 53.26832718666667},
#  'Manipur': {'2005': 35.619585054634264,
#   '2006': 34.87899721099272,
#   '2007': 29.57572751366667,
#   '2008': 36.085,
#   '2009': 34.96149419874509,
#   '2010': 31.126222612857468,
#   '2011': 31.647724362755515,
#   '2012': 35.719237024769875,
#   '2013': 39.21436160816259,
#   '2014': 34.06045667130619},
#  'Meghalaya': {'2005': 24.969255814,
#   '2006': 26.434082892666666,
#   '2007': 27.898909971000002,
#   '2008': 37.188101413333335,
#   '2009': 31.976023583333333,
#   '2010': 46.19124264333333,
#   '2011': 39.25246132333333,
#   '2012': 30.712564706,
#   '2013': 24.599192752666667,
#   '2014': 23.997732295000002},
#  'Mizoram': {'2005': 14.34739241,
#   '2006': 17.709555443333336,
#   '2007': 17.681853383666667,
#   '2008': 16.250164278,
#   '2009': 16.309875585333334,
#   '2010': 16.369586896,
#   '2011': 15.686458884666665,
#   '2012': 21.140661937,
#   '2013': 19.185299259,
#   '2014': 17.100292397333334},
#  'Nagaland': {'2005': 32.31531380033333,
#   '2006': 30.049123990333335,
#   '2007': 28.21554054066667,
#   '2008': 30.55817901333333,
#   '2009': 33.155185186666664,
#   '2010': 27.043311349999996,
#   '2011': 30.161057691000003,
#   '2012': 31.750643695,
#   '2013': 33.340229695666665,
#   '2014': 34.929815696333335},
#  'Odisha': {'2005': 32.33029316133333,
#   '2006': 33.020241158666664,
#   '2007': 32.572352653,
#   '2008': 35.838101613,
#   '2009': 36.419685789000006,
#   '2010': 35.58955970633333,
#   '2011': 37.894119380666666,
#   '2012': 35.24175145466667,
#   '2013': 35.686962826666665,
#   '2014': 37.640302123},
#  'Puducherry': {'2005': 27.01674198,
#   '2006': 26.441165746333333,
#   '2007': 20.823867911666667,
#   '2008': 21.371797123333334,
#   '2009': 17.019783902333334,
#   '2010': 18.86658823533333,
#   '2011': 21.564401844666666,
#   '2012': 20.459871175666663,
#   '2013': 20.94076211133333,
#   '2014': 20.44508795},
#  'Punjab': {'2005': 89.23606592333334,
#   '2006': 86.42177900666665,
#   '2007': 81.31777529666667,
#   '2008': 86.31974249666666,
#   '2009': 80.81254517233333,
#   '2010': 77.10329819666666,
#   '2011': 66.93560124666666,
#   '2012': 66.08850686866667,
#   '2013': 63.669197828,
#   '2014': 54.96318072466667},
#  'Rajasthan': {'2005': 45.79881320733333,
#   '2006': 51.77853085933333,
#   '2007': 49.09061110066666,
#   '2008': 55.03190405033334,
#   '2009': 54.765187805,
#   '2010': 67.033509758,
#   '2011': 66.48495537366666,
#   '2012': 70.81429854699999,
#   '2013': 69.97913460633333,
#   '2014': 67.84743494966666},
#  'Sikkim': {'2005': 29.283094050996198,
#   '2006': 26.86503448861362,
#   '2007': 26.2,
#   '2008': 29.03717990612017,
#   '2009': 36.66069985387943,
#   '2010': 29.60161442310237,
#   '2011': 35.79895278787389,
#   '2012': 55.388781282617856,
#   '2013': 35.267865488450155,
#   '2014': 27.831472608826527},
#  'Tamil Nadu': {'2005': 30.78998415666667,
#   '2006': 32.27831765333333,
#   '2007': 33.451524156666665,
#   '2008': 34.68229882333333,
#   '2009': 34.70200551666667,
#   '2010': 32.832179223333334,
#   '2011': 36.905936366666666,
#   '2012': 34.51913866666666,
#   '2013': 35.03583845666667,
#   '2014': 32.04472498},
#  'Uttar Pradesh': {'2005': 70.60329087000001,
#   '2006': 71.58846273333334,
#   '2007': 70.33547986,
#   '2008': 74.35058758,
#   '2009': 72.53093669666667,
#   '2010': 75.56912624333334,
#   '2011': 67.19681935999999,
#   '2012': 77.75683817,
#   '2013': 74.07795273666667,
#   '2014': 72.22618464333334},
#  'Uttarakhand': {'2005': 66.76082572,
#   '2006': 57.875432749999995,
#   '2007': 51.108553783333335,
#   '2008': 58.871937323333334,
#   '2009': 64.41094991333334,
#   '2010': 69.9499625,
#   '2011': 68.8465582,
#   '2012': 78.71195176666667,
#   '2013': 63.69511871666667,
#   '2014': 48.67828566},
#  'West Bengal': {'2005': 61.078471643,
#   '2006': 59.050343790666666,
#   '2007': 56.08946359866667,
#   '2008': 60.89176869333333,
#   '2009': 76.46730475000001,
#   '2010': 61.03179535899999,
#   '2011': 63.76259606333333,
#   '2012': 67.41182466333333,
#   '2013': 77.25285861,
#   '2014': 60.336652132333334}}

# %%
air_nbr_data=[]
for (k1,v1) in air_quality_mpc.items():
    for (k2,v2) in v1.items():
        nbr_mpc=[]
        for ele in neighbor[k1]:
            nbr_mpc.append(air_quality_mpc[ele][k2])
        if(len(nbr_mpc)<2):
            nbr_mean=round(nbr_mpc[0],3)
            nbr_std=round(0,3)
            zscore=round(0,3)
        else:
            nbr_mean=round(statistics.mean(nbr_mpc),3)
            nbr_std=round(statistics.stdev(nbr_mpc,nbr_mean),3)
            zscore = round((v2-nbr_mean)/nbr_std,3)
        if (v2>(nbr_mean+nbr_std)):
            spot = 1
        else:
            spot = 0
        air_nbr_data.append([k1,k2,round(v2,3),zscore,spot])
air_nbr_data
# Out:
# [['Andhra Pradesh', '2005', 38.531, -0.204, 0],
#  ['Andhra Pradesh', '2006', 40.504, 0.042, 0],
#  ['Andhra Pradesh', '2007', 38.363, -0.252, 0],
#  ['Andhra Pradesh', '2008', 38.201, -0.516, 0],
#  ['Andhra Pradesh', '2009', 37.408, -0.617, 0],
#  ['Andhra Pradesh', '2010', 30.083, -1.083, 0],
#  ['Andhra Pradesh', '2011', 35.835, -0.755, 0],
#  ['Andhra Pradesh', '2012', 33.621, -1.091, 0],
#  ['Andhra Pradesh', '2013', 33.809, -0.963, 0],
#  ['Andhra Pradesh', '2014', 34.046, -0.922, 0],
#  ['Arunachal Pradesh', '2005', 29.718, -0.999, 0],
#  ['Arunachal Pradesh', '2006', 26.449, -1.269, 0],
#  ['Arunachal Pradesh', '2007', 24.291, -1.473, 0],
#  ['Arunachal Pradesh', '2008', 26.171, -1.625, 0],
#  ['Arunachal Pradesh', '2009', 27.966, -1.831, 0],
#  ['Arunachal Pradesh', '2010', 23.007, -1.455, 0],
#  ['Arunachal Pradesh', '2011', 24.043, -2.769, 0],
#  ['Arunachal Pradesh', '2012', 24.542, -5.157, 0],
#  ['Arunachal Pradesh', '2013', 31.312, -0.89, 0],
#  ['Arunachal Pradesh', '2014', 25.467, -11.91, 0],
#  ['Assam', '2005', 44.886, 0.761, 0],
#  ['Assam', '2006', 39.115, 0.471, 0],
#  ['Assam', '2007', 35.462, 0.367, 0],
#  ['Assam', '2008', 37.319, 0.186, 0],
#  ['Assam', '2009', 39.686, 0.14, 0],
#  ['Assam', '2010', 34.676, 0.033, 0],
#  ['Assam', '2011', 34.359, 0.016, 0],
#  ['Assam', '2012', 34.041, -0.07, 0],
#  ['Assam', '2013', 49.02, 0.558, 0],
#  ['Assam', '2014', 33.868, 0.081, 0],
#  ['Bihar', '2005', 49.912, -2.978, 0],
#  ['Bihar', '2006', 53.504, -1.64, 0],
#  ['Bihar', '2007', 55.894, -1.147, 0],
#  ['Bihar', '2008', 54.61, -1.865, 0],
#  ['Bihar', '2009', 45.268, -5.088, 0],
#  ['Bihar', '2010', 69.295, -0.37, 0],
#  ['Bihar', '2011', 66.005, -0.518, 0],
#  ['Bihar', '2012', 67.298, -1.162, 0],
#  ['Bihar', '2013', 68.59, -1.955, 0],
#  ['Bihar', '2014', 69.883, 0.311, 0],
#  ['Chandigarh', '2005', 38.482, -1.3, 0],
#  ['Chandigarh', '2006', 41.255, -1.599, 0],
#  ['Chandigarh', '2007', 41.025, -0.802, 0],
#  ['Chandigarh', '2008', 38.913, -2.206, 0],
#  ['Chandigarh', '2009', 34.036, -3.445, 0],
#  ['Chandigarh', '2010', 36.557, -4.767, 0],
#  ['Chandigarh', '2011', 39.828, -6.771, 0],
#  ['Chandigarh', '2012', 44.259, -89.129, 0],
#  ['Chandigarh', '2013', 43.921, -2.929, 0],
#  ['Chandigarh', '2014', 38.141, -2.108, 0],
#  ['Chhattisgarh', '2005', 58.058, 0.434, 0],
#  ['Chhattisgarh', '2006', 57.547, 0.314, 0],
#  ['Chhattisgarh', '2007', 53.101, 0.109, 0],
#  ['Chhattisgarh', '2008', 56.947, 0.126, 0],
#  ['Chhattisgarh', '2009', 57.51, 0.13, 0],
#  ['Chhattisgarh', '2010', 61.96, 0.332, 0],
#  ['Chhattisgarh', '2011', 57.917, 0.125, 0],
#  ['Chhattisgarh', '2012', 43.387, -0.582, 0],
#  ['Chhattisgarh', '2013', 50.329, -0.215, 0],
#  ['Chhattisgarh', '2014', 49.634, -0.213, 0],
#  ['Dadra & Nagar Haveli', '2005', 38.301, -2.236, 0],
#  ['Dadra & Nagar Haveli', '2006', 38.925, -1.462, 0],
#  ['Dadra & Nagar Haveli', '2007', 39.549, -19.562, 0],
#  ['Dadra & Nagar Haveli', '2008', 40.173, -0.931, 0],
#  ['Dadra & Nagar Haveli', '2009', 32.38, -5.128, 0],
#  ['Dadra & Nagar Haveli', '2010', 21.365, -5.057, 0],
#  ['Dadra & Nagar Haveli', '2011', 16.935, -3.962, 0],
#  ['Dadra & Nagar Haveli', '2012', 12.058, -9.069, 0],
#  ['Dadra & Nagar Haveli', '2013', 7.181, -5.073, 0],
#  ['Dadra & Nagar Haveli', '2014', 2.304, -4.922, 0],
#  ['Daman & Diu', '2005', 41.374, 0, 0],
#  ['Daman & Diu', '2006', 41.236, 0, 0],
#  ['Daman & Diu', '2007', 41.098, 0, 0],
#  ['Daman & Diu', '2008', 40.96, 0, 0],
#  ['Daman & Diu', '2009', 27.743, 0, 0],
#  ['Daman & Diu', '2010', 20.052, 0, 0],
#  ['Daman & Diu', '2011', 17.034, 0, 0],
#  ['Daman & Diu', '2012', 13.484, 0, 0],
#  ['Daman & Diu', '2013', 9.935, 0, 0],
#  ['Daman & Diu', '2014', 6.385, 0, 0],
#  ['Delhi', '2005', 65.793, 0.31, 0],
#  ['Delhi', '2006', 73.082, 0.871, 0],
#  ['Delhi', '2007', 76.988, 1.059, 1],
#  ['Delhi', '2008', 94.49, 3.286, 1],
#  ['Delhi', '2009', 102.658, 0.606, 0],
#  ['Delhi', '2010', 98.999, 4.413, 1],
#  ['Delhi', '2011', 95.341, 8.094, 1],
#  ['Delhi', '2012', 108.642, 4.343, 1],
#  ['Delhi', '2013', 107.477, 21.151, 1],
#  ['Delhi', '2014', 95.248, 118.166, 1],
#  ['Goa', '2005', 26.364, -1.719, 0],
#  ['Goa', '2006', 23.835, -2.163, 0],
#  ['Goa', '2007', 22.863, -3.051, 0],
#  ['Goa', '2008', 37.939, -0.784, 0],
#  ['Goa', '2009', 30.297, -2.385, 0],
#  ['Goa', '2010', 33.96, -1.04, 0],
#  ['Goa', '2011', 39.877, -0.289, 0],
#  ['Goa', '2012', 35.016, -1.501, 0],
#  ['Goa', '2013', 24.11, -1.996, 0],
#  ['Goa', '2014', 22.127, -2.284, 0],
#  ['Gujarat', '2005', 57.071, 3.638, 1],
#  ['Gujarat', '2006', 52.253, 1.761, 1],
#  ['Gujarat', '2007', 45.885, 0.42, 0],
#  ['Gujarat', '2008', 41.564, -0.916, 0],
#  ['Gujarat', '2009', 44.011, 0.118, 0],
#  ['Gujarat', '2010', 42.319, -0.001, 0],
#  ['Gujarat', '2011', 42.808, 0.03, 0],
#  ['Gujarat', '2012', 45.522, 0.211, 0],
#  ['Gujarat', '2013', 39.148, -0.005, 0],
#  ['Gujarat', '2014', 40.465, 0.15, 0],
#  ['Haryana', '2005', 53.476, -0.064, 0],
#  ['Haryana', '2006', 58.718, -0.077, 0],
#  ['Haryana', '2007', 43.57, -0.775, 0],
#  ['Haryana', '2008', 63.304, -0.073, 0],
#  ['Haryana', '2009', 104.975, 1.555, 1],
#  ['Haryana', '2010', 66.628, 0.031, 0],
#  ['Haryana', '2011', 61.809, -0.007, 0],
#  ['Haryana', '2012', 65.745, -0.061, 0],
#  ['Haryana', '2013', 76.239, 0.411, 0],
#  ['Haryana', '2014', 71.948, 0.5, 0],
#  ['Himachal Pradesh', '2005', 20.466, -1.641, 0],
#  ['Himachal Pradesh', '2006', 37.248, -1.064, 0],
#  ['Himachal Pradesh', '2007', 34.721, -1.038, 0],
#  ['Himachal Pradesh', '2008', 41.049, -1.201, 0],
#  ['Himachal Pradesh', '2009', 38.084, -1.454, 0],
#  ['Himachal Pradesh', '2010', 40.054, -2.004, 0],
#  ['Himachal Pradesh', '2011', 35.99, -2.178, 0],
#  ['Himachal Pradesh', '2012', 36.362, -2.3, 0],
#  ['Himachal Pradesh', '2013', 35.87, -2.4, 0],
#  ['Himachal Pradesh', '2014', 35.312, -1.916, 0],
#  ['Jammu & Kashmir', '2005', 23.278, -0.649, 0],
#  ['Jammu & Kashmir', '2006', 27.451, -0.989, 0],
#  ['Jammu & Kashmir', '2007', 31.624, -0.801, 0],
#  ['Jammu & Kashmir', '2008', 35.797, -0.871, 0],
#  ['Jammu & Kashmir', '2009', 39.97, -0.645, 0],
#  ['Jammu & Kashmir', '2010', 44.143, -0.551, 0],
#  ['Jammu & Kashmir', '2011', 41.031, -0.477, 0],
#  ['Jammu & Kashmir', '2012', 45.858, -0.255, 0],
#  ['Jammu & Kashmir', '2013', 45.869, -0.198, 0],
#  ['Jammu & Kashmir', '2014', 47.004, 0.134, 0],
#  ['Jharkhand', '2005', 72.393, 1.251, 1],
#  ['Jharkhand', '2006', 78.608, 1.691, 1],
#  ['Jharkhand', '2007', 74.546, 1.546, 1],
#  ['Jharkhand', '2008', 77.087, 1.483, 1],
#  ['Jharkhand', '2009', 85.122, 1.6, 1],
#  ['Jharkhand', '2010', 84.38, 1.556, 1],
#  ['Jharkhand', '2011', 83.11, 2.031, 1],
#  ['Jharkhand', '2012', 79.486, 1.181, 1],
#  ['Jharkhand', '2013', 71.459, 0.582, 0],
#  ['Jharkhand', '2014', 70.983, 0.903, 0],
#  ['Karnataka', '2005', 35.412, 0.01, 0],
#  ['Karnataka', '2006', 33.844, -0.07, 0],
#  ['Karnataka', '2007', 37.518, 0.44, 0],
#  ['Karnataka', '2008', 38.578, 0.163, 0],
#  ['Karnataka', '2009', 39.758, 0.561, 0],
#  ['Karnataka', '2010', 36.848, 0.346, 0],
#  ['Karnataka', '2011', 33.937, -0.287, 0],
#  ['Karnataka', '2012', 40.828, 0.53, 0],
#  ['Karnataka', '2013', 36.22, 0.287, 0],
#  ['Karnataka', '2014', 38.543, 0.453, 0],
#  ['Kerala', '2005', 32.905, -0.06, 0],
#  ['Kerala', '2006', 31.77, -1.166, 0],
#  ['Kerala', '2007', 25.552, -3.454, 0],
#  ['Kerala', '2008', 24.04, -4.57, 0],
#  ['Kerala', '2009', 23.235, -3.915, 0],
#  ['Kerala', '2010', 20.253, -5.138, 0],
#  ['Kerala', '2011', 20.274, -7.217, 0],
#  ['Kerala', '2012', 23.481, -3.181, 0],
#  ['Kerala', '2013', 23.464, -14.532, 0],
#  ['Kerala', '2014', 22.569, -2.769, 0],
#  ['Madhya Pradesh', '2005', 42.419, -1.374, 0],
#  ['Madhya Pradesh', '2006', 42.919, -1.199, 0],
#  ['Madhya Pradesh', '2007', 45.144, -0.771, 0],
#  ['Madhya Pradesh', '2008', 52.576, -0.256, 0],
#  ['Madhya Pradesh', '2009', 50.428, -0.443, 0],
#  ['Madhya Pradesh', '2010', 54.129, -0.377, 0],
#  ['Madhya Pradesh', '2011', 55.969, -0.172, 0],
#  ['Madhya Pradesh', '2012', 52.618, -0.328, 0],
#  ['Madhya Pradesh', '2013', 59.808, 0.216, 0],
#  ['Madhya Pradesh', '2014', 50.241, -0.491, 0],
#  ['Maharashtra', '2005', 48.053, 0.498, 0],
#  ['Maharashtra', '2006', 43.564, 0.193, 0],
#  ['Maharashtra', '2007', 46.36, 0.637, 0],
#  ['Maharashtra', '2008', 50.371, 0.859, 0],
#  ['Maharashtra', '2009', 47.732, 0.62, 0],
#  ['Maharashtra', '2010', 49.131, 0.645, 0],
#  ['Maharashtra', '2011', 54.051, 0.973, 0],
#  ['Maharashtra', '2012', 51.181, 1.05, 1],
#  ['Maharashtra', '2013', 49.505, 0.8, 0],
#  ['Maharashtra', '2014', 53.268, 1.145, 1],
#  ['Manipur', '2005', 35.62, 0.333, 0],
#  ['Manipur', '2006', 34.879, 0.551, 0],
#  ['Manipur', '2007', 29.576, 0.275, 0],
#  ['Manipur', '2008', 36.085, 0.748, 0],
#  ['Manipur', '2009', 34.961, 0.435, 0],
#  ['Manipur', '2010', 31.126, 0.554, 0],
#  ['Manipur', '2011', 31.648, 0.502, 0],
#  ['Manipur', '2012', 35.719, 0.979, 0],
#  ['Manipur', '2013', 39.214, 0.36, 0],
#  ['Manipur', '2014', 34.06, 0.543, 0],
#  ['Meghalaya', '2005', 24.969, 0, 0],
#  ['Meghalaya', '2006', 26.434, 0, 0],
#  ['Meghalaya', '2007', 27.899, 0, 0],
#  ['Meghalaya', '2008', 37.188, 0, 0],
#  ['Meghalaya', '2009', 31.976, 0, 0],
#  ['Meghalaya', '2010', 46.191, 0, 1],
#  ['Meghalaya', '2011', 39.252, 0, 1],
#  ['Meghalaya', '2012', 30.713, 0, 0],
#  ['Meghalaya', '2013', 24.599, 0, 0],
#  ['Meghalaya', '2014', 23.998, 0, 0],
#  ['Mizoram', '2005', 14.347, -3.954, 0],
#  ['Mizoram', '2006', 17.71, -6.44, 0],
#  ['Mizoram', '2007', 17.682, -3.565, 0],
#  ['Mizoram', '2008', 16.25, -23.454, 0],
#  ['Mizoram', '2009', 16.31, -6.292, 0],
#  ['Mizoram', '2010', 16.37, -6.586, 0],
#  ['Mizoram', '2011', 15.686, -9.033, 0],
#  ['Mizoram', '2012', 21.141, -11.585, 0],
#  ['Mizoram', '2013', 19.185, -3.596, 0],
#  ['Mizoram', '2014', 17.1, -123.998, 0],
#  ['Nagaland', '2005', 32.315, -0.579, 0],
#  ['Nagaland', '2006', 30.049, -0.532, 0],
#  ['Nagaland', '2007', 28.216, -0.279, 0],
#  ['Nagaland', '2008', 30.558, -0.431, 0],
#  ['Nagaland', '2009', 33.155, -0.178, 0],
#  ['Nagaland', '2010', 27.043, -0.428, 0],
#  ['Nagaland', '2011', 30.161, 0.027, 0],
#  ['Nagaland', '2012', 31.751, 0.053, 0],
#  ['Nagaland', '2013', 33.34, -0.734, 0],
#  ['Nagaland', '2014', 34.93, 0.774, 0],
#  ['Odisha', '2005', 32.33, -1.789, 0],
#  ['Odisha', '2006', 33.02, -1.662, 0],
#  ['Odisha', '2007', 32.572, -1.544, 0],
#  ['Odisha', '2008', 35.838, -1.405, 0],
#  ['Odisha', '2009', 36.42, -1.306, 0],
#  ['Odisha', '2010', 35.59, -1.066, 0],
#  ['Odisha', '2011', 37.894, -1.144, 0],
#  ['Odisha', '2012', 35.242, -0.98, 0],
#  ['Odisha', '2013', 35.687, -1.128, 0],
#  ['Odisha', '2014', 37.64, -1.022, 0],
#  ['Puducherry', '2005', 27.017, 0, 0],
#  ['Puducherry', '2006', 26.441, 0, 0],
#  ['Puducherry', '2007', 20.824, 0, 0],
#  ['Puducherry', '2008', 21.372, 0, 0],
#  ['Puducherry', '2009', 17.02, 0, 0],
#  ['Puducherry', '2010', 18.867, 0, 0],
#  ['Puducherry', '2011', 21.564, 0, 0],
#  ['Puducherry', '2012', 20.46, 0, 0],
#  ['Puducherry', '2013', 20.941, 0, 0],
#  ['Puducherry', '2014', 20.445, 0, 0],
#  ['Punjab', '2005', 89.236, 3.719, 1],
#  ['Punjab', '2006', 86.422, 3.517, 1],
#  ['Punjab', '2007', 81.318, 5.925, 1],
#  ['Punjab', '2008', 86.32, 3.349, 1],
#  ['Punjab', '2009', 80.813, 0.901, 0],
#  ['Punjab', '2010', 77.103, 1.771, 1],
#  ['Punjab', '2011', 66.936, 1.277, 1],
#  ['Punjab', '2012', 66.089, 0.907, 0],
#  ['Punjab', '2013', 63.669, 0.527, 0],
#  ['Punjab', '2014', 54.963, 0.172, 0],
#  ['Rajasthan', '2005', 45.799, -0.932, 0],
#  ['Rajasthan', '2006', 51.779, -0.623, 0],
#  ['Rajasthan', '2007', 49.091, -0.468, 0],
#  ['Rajasthan', '2008', 55.032, -0.488, 0],
#  ['Rajasthan', '2009', 54.765, -0.644, 0],
#  ['Rajasthan', '2010', 67.034, 0.262, 0],
#  ['Rajasthan', '2011', 66.485, 0.745, 0],
#  ['Rajasthan', '2012', 70.814, 0.734, 0],
#  ['Rajasthan', '2013', 69.979, 0.499, 0],
#  ['Rajasthan', '2014', 67.847, 0.71, 0],
#  ['Sikkim', '2005', 29.283, 0, 0],
#  ['Sikkim', '2006', 26.865, 0, 0],
#  ['Sikkim', '2007', 26.2, 0, 0],
#  ['Sikkim', '2008', 29.037, 0, 0],
#  ['Sikkim', '2009', 36.661, 0, 0],
#  ['Sikkim', '2010', 29.602, 0, 0],
#  ['Sikkim', '2011', 35.799, 0, 0],
#  ['Sikkim', '2012', 55.389, 0, 0],
#  ['Sikkim', '2013', 35.268, 0, 0],
#  ['Sikkim', '2014', 27.831, 0, 0],
#  ['Tamil Nadu', '2005', 30.79, -0.549, 0],
#  ['Tamil Nadu', '2006', 32.278, -0.148, 0],
#  ['Tamil Nadu', '2007', 33.452, 0.33, 0],
#  ['Tamil Nadu', '2008', 34.682, 0.453, 0],
#  ['Tamil Nadu', '2009', 34.702, 0.486, 0],
#  ['Tamil Nadu', '2010', 32.832, 0.743, 0],
#  ['Tamil Nadu', '2011', 36.906, 1.109, 1],
#  ['Tamil Nadu', '2012', 34.519, 0.525, 0],
#  ['Tamil Nadu', '2013', 35.036, 0.853, 0],
#  ['Tamil Nadu', '2014', 32.045, 0.358, 0],
#  ['Uttar Pradesh', '2005', 70.603, 1.131, 1],
#  ['Uttar Pradesh', '2006', 71.588, 1.135, 1],
#  ['Uttar Pradesh', '2007', 70.335, 1.19, 1],
#  ['Uttar Pradesh', '2008', 74.351, 0.82, 0],
#  ['Uttar Pradesh', '2009', 72.531, 0.223, 0],
#  ['Uttar Pradesh', '2010', 75.569, 0.449, 0],
#  ['Uttar Pradesh', '2011', 67.197, 0.088, 0],
#  ['Uttar Pradesh', '2012', 77.757, 0.497, 0],
#  ['Uttar Pradesh', '2013', 74.078, 0.359, 0],
#  ['Uttar Pradesh', '2014', 72.226, 0.56, 0],
#  ['Uttarakhand', '2005', 66.761, 0.599, 0],
#  ['Uttarakhand', '2006', 57.875, 0.142, 0],
#  ['Uttarakhand', '2007', 51.109, -0.056, 0],
#  ['Uttarakhand', '2008', 58.872, 0.05, 0],
#  ['Uttarakhand', '2009', 64.411, 0.374, 0],
#  ['Uttarakhand', '2010', 69.95, 0.483, 0],
#  ['Uttarakhand', '2011', 68.847, 0.782, 0],
#  ['Uttarakhand', '2012', 78.712, 0.74, 0],
#  ['Uttarakhand', '2013', 63.695, 0.323, 0],
#  ['Uttarakhand', '2014', 48.678, -0.195, 0],
#  ['West Bengal', '2005', 61.078, 0.892, 0],
#  ['West Bengal', '2006', 59.05, 0.622, 0],
#  ['West Bengal', '2007', 56.089, 0.559, 0],
#  ['West Bengal', '2008', 60.892, 0.728, 0],
#  ['West Bengal', '2009', 76.467, 1.344, 1],
#  ['West Bengal', '2010', 61.032, 0.421, 0],
#  ['West Bengal', '2011', 63.763, 0.561, 0],
#  ['West Bengal', '2012', 67.412, 0.661, 0],
#  ['West Bengal', '2013', 77.253, 1.452, 1],
#  ['West Bengal', '2014', 60.337, 0.593, 0]]

# %%
df= pd.DataFrame(air_nbr_data,columns=['State','Year','Mpc','zscore','spot'])
df
# Out:
#               State  Year     Mpc  zscore  spot
# 0    Andhra Pradesh  2005  38.531  -0.204     0
# 1    Andhra Pradesh  2006  40.504   0.042     0
# 2    Andhra Pradesh  2007  38.363  -0.252     0
# 3    Andhra Pradesh  2008  38.201  -0.516     0
# 4    Andhra Pradesh  2009  37.408  -0.617     0
# ..              ...   ...     ...     ...   ...
# 315     West Bengal  2010  61.032   0.421     0
# 316     West Bengal  2011  63.763   0.561     0
# 317     West Bengal  2012  67.412   0.661     0
# 318     West Bengal  2013  77.253   1.452     1
# 319     West Bengal  2014  60.337   0.593     0
#
# [320 rows x 5 columns]

# %%
df.to_csv("Air_Quality_Mpc_zscore.csv",index=False)

# %%
zscore_nbr=df.sort_values(['Year','zscore'],ascending=[True, False])
zscore_nbr.reset_index(drop=True,inplace=True)
zscore_nbr
# Out:
#                     State  Year     Mpc   zscore  spot
# 0                  Punjab  2005  89.236    3.719     1
# 1                 Gujarat  2005  57.071    3.638     1
# 2               Jharkhand  2005  72.393    1.251     1
# 3           Uttar Pradesh  2005  70.603    1.131     1
# 4             West Bengal  2005  61.078    0.892     0
# ..                    ...   ...     ...      ...   ...
# 315                   Goa  2014  22.127   -2.284     0
# 316                Kerala  2014  22.569   -2.769     0
# 317  Dadra & Nagar Haveli  2014   2.304   -4.922     0
# 318     Arunachal Pradesh  2014  25.467  -11.910     0
# 319               Mizoram  2014  17.100 -123.998     0
#
# [320 rows x 5 columns]

# %%
zscore_nbr.head(33)
# Out:
#                    State  Year     Mpc  zscore  spot
# 0                 Punjab  2005  89.236   3.719     1
# 1                Gujarat  2005  57.071   3.638     1
# 2              Jharkhand  2005  72.393   1.251     1
# 3          Uttar Pradesh  2005  70.603   1.131     1
# 4            West Bengal  2005  61.078   0.892     0
# 5                  Assam  2005  44.886   0.761     0
# 6            Uttarakhand  2005  66.761   0.599     0
# 7            Maharashtra  2005  48.053   0.498     0
# 8           Chhattisgarh  2005  58.058   0.434     0
# 9                Manipur  2005  35.620   0.333     0
# 10                 Delhi  2005  65.793   0.310     0
# 11             Karnataka  2005  35.412   0.010     0
# 12           Daman & Diu  2005  41.374   0.000     0
# 13             Meghalaya  2005  24.969   0.000     0
# 14            Puducherry  2005  27.017   0.000     0
# 15                Sikkim  2005  29.283   0.000     0
# 16                Kerala  2005  32.905  -0.060     0
# 17               Haryana  2005  53.476  -0.064     0
# 18        Andhra Pradesh  2005  38.531  -0.204     0
# 19            Tamil Nadu  2005  30.790  -0.549     0
# 20              Nagaland  2005  32.315  -0.579     0
# 21       Jammu & Kashmir  2005  23.278  -0.649     0
# 22             Rajasthan  2005  45.799  -0.932     0
# 23     Arunachal Pradesh  2005  29.718  -0.999     0
# 24            Chandigarh  2005  38.482  -1.300     0
# 25        Madhya Pradesh  2005  42.419  -1.374     0
# 26      Himachal Pradesh  2005  20.466  -1.641     0
# 27                   Goa  2005  26.364  -1.719     0
# 28                Odisha  2005  32.330  -1.789     0
# 29  Dadra & Nagar Haveli  2005  38.301  -2.236     0
# 30                 Bihar  2005  49.912  -2.978     0
# 31               Mizoram  2005  14.347  -3.954     0
# 32                Punjab  2006  86.422   3.517     1

# %%
topSpots_df = pd.DataFrame(columns=['Year','spot','State1','State2','State3','State4','State5'])
i=0
while(i<320):
    hotstate_list=[]
    coldstate_list=[]
    hotstate = zscore_nbr[i:i+32].head(5)
    coldstate = zscore_nbr[i+27:i+32]
    year_id = str(int(hotstate.iloc[0]['Year']))
    hotstate_list=list(hotstate['State'])
    coldstate_list=list(coldstate['State'])
    topSpots_df=topSpots_df.append({'Year':year_id,'spot': 'hot','State1':hotstate_list[0],'State2':hotstate_list[1],'State3':hotstate_list[2],'State4':hotstate_list[3],'State5':hotstate_list[4]},ignore_index=True)
    topSpots_df=topSpots_df.append({'Year':year_id,'spot': 'cold','State1':coldstate_list[0],'State2':coldstate_list[1],'State3':coldstate_list[2],'State4':coldstate_list[3],'State5':coldstate_list[4]},ignore_index=True)  
    i+=32
topSpots_df
# Out:
#     Year  spot             State1                State2                State3  \
# 0   2005   hot             Punjab               Gujarat             Jharkhand
# 1   2005  cold                Goa                Odisha  Dadra & Nagar Haveli
# 2   2006   hot             Punjab               Gujarat             Jharkhand
# 3   2006  cold         Chandigarh                 Bihar                Odisha
# 4   2007   hot             Punjab             Jharkhand         Uttar Pradesh
# 5   2007  cold             Odisha                   Goa                Kerala
# 6   2008   hot             Punjab                 Delhi             Jharkhand
# 7   2008  cold  Arunachal Pradesh                 Bihar            Chandigarh
# 8   2009   hot          Jharkhand               Haryana           West Bengal
# 9   2009  cold         Chandigarh                Kerala                 Bihar
# 10  2010   hot              Delhi                Punjab             Jharkhand
# 11  2010  cold   Himachal Pradesh            Chandigarh  Dadra & Nagar Haveli
# 12  2011   hot              Delhi             Jharkhand                Punjab
# 13  2011  cold  Arunachal Pradesh  Dadra & Nagar Haveli            Chandigarh
# 14  2012   hot              Delhi             Jharkhand           Maharashtra
# 15  2012  cold             Kerala     Arunachal Pradesh  Dadra & Nagar Haveli
# 16  2013   hot              Delhi           West Bengal            Tamil Nadu
# 17  2013  cold   Himachal Pradesh            Chandigarh               Mizoram
# 18  2014   hot              Delhi           Maharashtra             Jharkhand
# 19  2014  cold                Goa                Kerala  Dadra & Nagar Haveli
#
#                   State4                State5
# 0          Uttar Pradesh           West Bengal
# 1                  Bihar               Mizoram
# 2          Uttar Pradesh                 Delhi
# 3                    Goa               Mizoram
# 4                  Delhi           Maharashtra
# 5                Mizoram  Dadra & Nagar Haveli
# 6            Maharashtra         Uttar Pradesh
# 7                 Kerala               Mizoram
# 8                 Punjab           Maharashtra
# 9   Dadra & Nagar Haveli               Mizoram
# 10            Tamil Nadu           Maharashtra
# 11                Kerala               Mizoram
# 12            Tamil Nadu           Maharashtra
# 13                Kerala               Mizoram
# 14               Manipur                Punjab
# 15               Mizoram            Chandigarh
# 16           Maharashtra             Jharkhand
# 17  Dadra & Nagar Haveli                Kerala
# 18              Nagaland             Rajasthan
# 19     Arunachal Pradesh               Mizoram

# %%
topSpots_df.to_csv("TopSpots.csv",index=False)

# %%
state_co=pd.read_csv('State-Coordinates.csv')
state_co
# Out:
#                    State        xco        yco
# 0         Andhra Pradesh  15.912900  79.740000
# 1      Arunachal Pradesh  28.218000  94.727800
# 2                  Assam  26.200600  92.937600
# 3                  Bihar  25.096100  85.313100
# 4             Chandigarh  30.733300  76.779400
# 5           Chhattisgarh  22.090420  82.159987
# 6   Dadra & Nagar Haveli  20.266578  73.016618
# 7            Daman & Diu  20.428300  72.839700
# 8                  Delhi  28.669993  77.230004
# 9                    Goa  15.491997  73.818001
# 10               Gujarat  22.258700  71.192400
# 11               Haryana  28.450006  77.019991
# 12      Himachal Pradesh  31.100025  77.166597
# 13       Jammu & Kashmir  34.299959  74.466658
# 14             Jharkhand  23.800393  86.419986
# 15             Karnataka  12.570381  76.919997
# 16                Kerala   8.900373  76.569993
# 17        Madhya Pradesh  21.300391  76.130019
# 18           Maharashtra  19.250232  73.160175
# 19               Manipur  24.799971  93.950017
# 20             Meghalaya  25.570492  91.880014
# 21               Mizoram  23.710399  92.720015
# 22              Nagaland  25.666998  94.116570
# 23                Odisha  19.820430  85.900017
# 24            Puducherry  11.934994  79.830000
# 25                Punjab  31.519974  75.980003
# 26             Rajasthan  26.449999  74.639981
# 27                Sikkim  27.333330  88.616647
# 28            Tamil Nadu  12.920386  79.150042
# 29         Uttar Pradesh  27.599981  78.050006
# 30           Uttarakhand  30.320409  78.050006
# 31           West Bengal  22.580390  88.329947

# %%
air_quality_map=pd.merge(df,state_co,on='State')
air_quality_map
# Out:
#               State  Year     Mpc  zscore  spot       xco        yco
# 0    Andhra Pradesh  2005  38.531  -0.204     0  15.91290  79.740000
# 1    Andhra Pradesh  2006  40.504   0.042     0  15.91290  79.740000
# 2    Andhra Pradesh  2007  38.363  -0.252     0  15.91290  79.740000
# 3    Andhra Pradesh  2008  38.201  -0.516     0  15.91290  79.740000
# 4    Andhra Pradesh  2009  37.408  -0.617     0  15.91290  79.740000
# ..              ...   ...     ...     ...   ...       ...        ...
# 315     West Bengal  2010  61.032   0.421     0  22.58039  88.329947
# 316     West Bengal  2011  63.763   0.561     0  22.58039  88.329947
# 317     West Bengal  2012  67.412   0.661     0  22.58039  88.329947
# 318     West Bengal  2013  77.253   1.452     1  22.58039  88.329947
# 319     West Bengal  2014  60.337   0.593     0  22.58039  88.329947
#
# [320 rows x 7 columns]

# %%
air_quality_map.to_csv("Air_Quality_MapFile.csv",index=False)
